# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
sns.set_palette("husl")

# %%
filename = 'log_gan2.csv'
col_names = ['epoch', 'd_loss', 'acc', 'acc_real', 'acc_fake', 'g_loss']
df = pd.read_csv(filename, delimiter=';', names=col_names)
df = df[df.epoch % 10 == 0]
df.head()
# Out:
#    epoch    d_loss         acc    acc_real  acc_fake    g_loss
# 0    100  0.072794  100.000000  100.000000     100.0  2.844763
# 1    200  0.514496   77.714288   55.428571     100.0  1.719460
# 2    300  0.511179   63.142860   26.285714     100.0  1.344699
# 3    400  0.617094   56.142855   12.285715     100.0  0.726997
# 4    500  0.621064   57.357144   14.714286     100.0  0.734552

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=df, x='epoch', y='d_loss', label='d_loss')
s = sns.lineplot(data=df, x='epoch', y='g_loss', label='g_loss')
s.set_ylabel('Loss')
s.set_xlabel('Epoch')
plt.savefig('gan-basic-loss.png')
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=df, x='epoch', y='acc', label='acc')
sns.lineplot(data=df, x='epoch', y='acc_real', label='acc_real')
s = sns.lineplot(data=df, x='epoch', y='acc_fake', label='acc_fake')
s.set_ylabel('Accuracy (%)')
s.set_xlabel('Epoch')
plt.savefig('gan-basic-acc.png')
plt.show()
